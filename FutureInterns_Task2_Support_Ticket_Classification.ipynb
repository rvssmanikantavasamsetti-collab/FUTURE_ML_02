# %% [markdown]
# <a href="https://colab.research.google.com/github/rvssmanikantavasamsetti-collab/FUTURE_ML_02/blob/main/FutureInterns_Task2_Support_Ticket_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Support Ticket Classification Project Started")
# Out:
# Support Ticket Classification Project Started

# %%
import pandas as pd

data = {
    'Ticket': [
        'Cannot login to account',
        'Payment failed during checkout',
        'Need password reset',
        'Website is very slow',
        'Refund not received'
    ],
    'Category': [
        'Account',
        'Billing',
        'Account',
        'Technical',
        'Billing'
    ]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                            Ticket   Category
# 0         Cannot login to account    Account
# 1  Payment failed during checkout    Billing
# 2             Need password reset    Account
# 3            Website is very slow  Technical
# 4             Refund not received    Billing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(df['Ticket'])

print("Shape:", X.shape)
# Out:
# Shape: (5, 18)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X, df['Category'])

new_ticket = ["I cannot access my account"]

prediction = model.predict(vectorizer.transform(new_ticket))

print("Predicted Category:", prediction[0])
# Out:
# Predicted Category: Account
